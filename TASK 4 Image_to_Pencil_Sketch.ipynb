# %%
#IMAGE TO PENCIL SKETCH

# %% [markdown]
# #This combined code includes both the image processing steps for converting an image to a pencil sketch and the user prompt for entering the blur amount. You can upload the image file when prompted, and the code will display both the original image and the generated pencil sketch image, allowing you to control the intensity of the effect.

# %%
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload the image file
uploaded = files.upload()

# Read the image
image_path = list(uploaded.keys())[0]
image = cv2.imread(image_path)

# Display the original image
cv2_imshow(image)

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Invert the grayscale image
inverted_gray_image = 255 - gray_image

# Blur the inverted image
blur_amount = int(input("Enter the blur amount (Recommended: 15): "))
blurred_img = cv2.GaussianBlur(inverted_gray_image, (blur_amount, blur_amount), 0)

# Invert the blurred image
inverted_blurred_img = 255 - blurred_img

# Create the pencil sketch image
pencil_sketch_img = cv2.divide(gray_image, inverted_blurred_img, scale=256.0)

# Display the pencil sketch image
cv2_imshow(pencil_sketch_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
#      <input type="file" id="files-354b43c0-d920-4b7d-8cbc-484418156a74" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-354b43c0-d920-4b7d-8cbc-484418156a74">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
